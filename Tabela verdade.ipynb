# %% [markdown]
# #Tabela verdade

# %%
[ ]
#and
print(10 > 2 and 4 < 6)
print(10 < 2 and 4 < 6)
True
False

[ ]
#or
print(10 > 2 or 10 < 2)
print(10 < 2 or 10 < 11)
True
True

[ ]
#not
not(10 > 2)
False
