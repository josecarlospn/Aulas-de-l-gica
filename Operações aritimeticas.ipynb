# %% [markdown]
# #Operações aritiméticas

# %%
[ ]
#adiçao
10 + 2
12

[ ]
#subtração
10-2
8

[ ]
#multiplicação
10*2
20

[ ]
#divisão
10/2
5.0

[ ]
#divisão inteira
10//2
5

[ ]
#resto da divisão
10%2
0

[ ]
#potenciação
10**2
100
# Out:
# 100
